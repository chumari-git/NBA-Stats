# %%
import pandas as pd

# %%
seasons = [2020, 2021, 2022, 2023, 2024]

# %%
def get_by_season(season: int):
    tables = pd.read_html(f"https://www.basketball-reference.com/leagues/NBA_{season}_standings.html")
    print(len(tables))

get_by_season(2024)
# Out:
# 4

# %%
tables[3]
# Out:
#          Western Conference                   W                   L  \
# 0        Northwest Division  Northwest Division  Northwest Division
# 1    Oklahoma City Thunder*                  57                  25
# 2           Denver Nuggets*                  57                  25
# 3   Minnesota Timberwolves*                  56                  26
# 4                 Utah Jazz                  31                  51
# 5    Portland Trail Blazers                  21                  61
# 6          Pacific Division    Pacific Division    Pacific Division
# 7     Los Angeles Clippers*                  51                  31
# 8             Phoenix Suns*                  49                  33
# 9       Los Angeles Lakers*                  47                  35
# 10         Sacramento Kings                  46                  36
# 11    Golden State Warriors                  46                  36
# 12       Southwest Division  Southwest Division  Southwest Division
# ...
